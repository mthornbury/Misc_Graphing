# %% [markdown]
# PHYC20090 Experiment #12 - Current Balance

# %%
import numpy as np
import matplotlib.pyplot as plt

y = np.array([9.61, 53.29, 65.61, 119.90, 136.89, 184.96])
x = np.array([0.000186787, 0.001035782, 0.001275242, 0.002330509, 0.00266069, 0.003595013])
plt.plot(x,y)
plt.grid()
plt.xlabel('Force (N)')
plt.ylabel('Current Squared')
plt.show()
